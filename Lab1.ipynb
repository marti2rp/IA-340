# %% [markdown]
# # Lab1

# %%
import pandas as pd

covid_data = pd.read_csv('s3://ia340-2025-fall-wei-demo-5465148971/data.csv')

covid_data.head()
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/fsspec/registry.py:298: UserWarning: Your installed version of s3fs is very old and known to cause
# severe performance issues, see also https://github.com/dask/dask/issues/10276
#
# To fix, you should specify a lower version bound on s3fs, or
# update the current installation.
#
#   warnings.warn(s3_msg)
#       dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0  14/12/2020   14     12  2020    746       6             Afghanistan    AF
# 1  13/12/2020   13     12  2020    298       9             Afghanistan    AF
# 2  12/12/2020   12     12  2020    113      11             Afghanistan    AF
# ...

# %%
crime_data = pd.read_csv('s3://ia340-2025-fall-wei-demo-5465148971/Crime_Incidents_in_2025.csv')

crime_data.head()
# Out:
#              X            Y       CCN              REPORT_DAT     SHIFT  \
# 0  400588.4650  129470.0424   5131706  2025/02/05 05:00:00+00  MIDNIGHT
# 1  405684.5761  135633.8979  10133557  2025/06/30 04:00:00+00  MIDNIGHT
# 2  397581.8300  141846.4300  25079053  2025/05/27 22:19:32+00   EVENING
# 3  399215.8700  138751.2000  25079273  2025/08/11 17:39:31+00       DAY
# 4  397700.5000  137976.2500  25421607  2025/05/05 18:31:00+00       DAY
#
#    METHOD      OFFENSE                                      BLOCK  \
# 0     GUN     HOMICIDE         800 - 899 BLOCK OF XENIA STREET SE
# 1     GUN     HOMICIDE           4600 - 4699 BLOCK OF A STREET SE
# 2  OTHERS      ROBBERY        4400 - 4499 BLOCK OF IOWA AVENUE NW
# 3  OTHERS      ROBBERY  1800 - 2199 BLOCK OF NORTH CAPITOL STREET
# 4  OTHERS  THEFT/OTHER           1000 - 1099 BLOCK OF P STREET NW
#
#           XBLOCK         YBLOCK  ...  BLOCK_GROUP CENSUS_TRACT  \
# 0  400588.464990  129470.042358  ...     009801 1       9801.0
# ...
